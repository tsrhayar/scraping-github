# %%
import csv
import requests
import sys

def save_repository_data_to_csv(query,num):
    url = 'https://api.github.com/search/repositories'

    headers = {
        'Authorization': 'Bearer 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'
    }

    params = {
        'q': query,
        'sort': 'stars',
        'order': 'desc',
        'per_page': '100',
        'page': '1',
    }

    # Send the GET request
    response = requests.get(url, headers=headers, params=params)
    data = response.json()

    total_count = data['total_count']

    # Save data in a CSV file
    filename = f'repositories/repository_data{num}.csv'
    fieldnames = [
            'Name', 'Description', 'Stars', 'URL',
            'Date creation', 'Dernier modification',
            'Forks', 'Language'
            ]

    with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        for item in data['items']:
            name = item['name']
            description = item['description']
            stars = item['stargazers_count']
            url = item['html_url']
            created_at = item['created_at']
            updated_at = item['updated_at']
            forks = item['forks_count']
            language = item['language']

            writer.writerow({
                'Name': name, 'Description': description,
                'Stars': stars, 'URL': url, 'Date creation': created_at,
                'Dernier modification': updated_at, 'Forks': forks, 'Language': language
                })
    percentage = total_count / 
    print(f'CSV file "{filename}" created successfully!')
    return {"my_count":total_count, "less_star" : stars, "percentage": percentage}
# ////////////////////////////
query = 'stars:>2500'
my_return = save_repository_data_to_csv(query,1)
my_count = my_return['my_count']
my_less_star =  my_return['less_star']
print("Total count:", my_return['my_count'])
print("less_star:", my_return['less_star'])

query = f'stars:2500..{my_less_star}'

my_counter = 2;
while my_count > 10:
    my_return = save_repository_data_to_csv(query,my_counter)
    my_count = my_return['my_count']
    my_less_star =  my_return['less_star']
    query = f'stars:2500..{my_less_star}'
    print(f'Il reste {my_count}')
    my_counter = my_counter + 1
    
# print('-----')

import glob
import pandas as pd

# Set the directory where the CSV files are located
directory = 'repositories/'

# Set the pattern of the CSV files you want to merge
pattern = 'repository_data*.csv'

# Get the list of files in the directory that match the pattern
csv_files = glob.glob(directory + pattern)

# Create an empty DataFrame to store the merged data
merged_data = pd.DataFrame()

# Iterate over the CSV files and merge them into the DataFrame
for file in csv_files:
    df = pd.read_csv(file)
    merged_data = pd.concat([merged_data, df], ignore_index=True)

# Save the merged data to a new CSV file
merged_data.to_csv('merged_file.csv', index=False)

print("CSV files merged successfully!")

# print('-----')
print('Terminé !')
# Out:
# CSV file "repositories/repository_data1.csv" created successfully!
# Total count: 16475
# less_star: 65188
# CSV file "repositories/repository_data2.csv" created successfully!
# Il reste 16381
# CSV file "repositories/repository_data3.csv" created successfully!
# Il reste 16282
# CSV file "repositories/repository_data4.csv" created successfully!
# Il reste 16183
# CSV file "repositories/repository_data5.csv" created successfully!
# Il reste 16084
# CSV file "repositories/repository_data6.csv" created successfully!
# Il reste 15985
# CSV file "repositories/repository_data7.csv" created successfully!
# Il reste 15886
# CSV file "repositories/repository_data8.csv" created successfully!
# Il reste 15787
# CSV file "repositories/repository_data9.csv" created successfully!
# Il reste 15688
# CSV file "repositories/repository_data10.csv" created successfully!
# Il reste 15590
# CSV file "repositories/repository_data11.csv" created successfully!
# Il reste 15491
# CSV file "repositories/repository_data12.csv" created successfully!
# Il reste 15392
# CSV file "repositories/repository_data13.csv" created successfully!
# Il reste 15293
# CSV file "repositories/repository_data14.csv" created successfully!
# Il reste 15194
# CSV file "repositories/repository_data15.csv" created successfully!
# Il reste 15095
# CSV file "repositories/repository_data16.csv" created successfully!
# Il reste 14996
# CSV file "repositories/repository_data17.csv" created successfully!
# Il reste 14898
# CSV file "repositories/repository_data18.csv" created successfully!
# Il reste 14799
# CSV file "repositories/repository_data19.csv" created successfully!
# Il reste 14700
# CSV file "repositories/repository_data20.csv" created successfully!
# Il reste 14601
# CSV file "repositories/repository_data21.csv" created successfully!
# Il reste 14502
# CSV file "repositories/repository_data22.csv" created successfully!
# Il reste 14403
# CSV file "repositories/repository_data23.csv" created successfully!
# Il reste 14304
# CSV file "repositories/repository_data24.csv" created successfully!
# Il reste 14205
# CSV file "repositories/repository_data25.csv" created successfully!
# Il reste 14106
# CSV file "repositories/repository_data26.csv" created successfully!
# Il reste 14007
# CSV file "repositories/repository_data27.csv" created successfully!
# Il reste 13909
# CSV file "repositories/repository_data28.csv" created successfully!
# Il reste 13810
# CSV file "repositories/repository_data29.csv" created successfully!
# Il reste 13711
# CSV file "repositories/repository_data30.csv" created successfully!
# Il reste 13612
# CSV file "repositories/repository_data31.csv" created successfully!
# Il reste 13513
# CSV file "repositories/repository_data32.csv" created successfully!
# Il reste 13414
# CSV file "repositories/repository_data33.csv" created successfully!
# Il reste 13317
# CSV file "repositories/repository_data34.csv" created successfully!
# Il reste 13218
# CSV file "repositories/repository_data35.csv" created successfully!
# Il reste 13119
# CSV file "repositories/repository_data36.csv" created successfully!
# Il reste 13020
# CSV file "repositories/repository_data37.csv" created successfully!
# Il reste 12921
# CSV file "repositories/repository_data38.csv" created successfully!
# Il reste 12822
# CSV file "repositories/repository_data39.csv" created successfully!
# Il reste 12724
# CSV file "repositories/repository_data40.csv" created successfully!
# Il reste 12625
# CSV file "repositories/repository_data41.csv" created successfully!
# Il reste 12526
# CSV file "repositories/repository_data42.csv" created successfully!
# Il reste 12427
# CSV file "repositories/repository_data43.csv" created successfully!
# Il reste 12331
# CSV file "repositories/repository_data44.csv" created successfully!
# Il reste 12232
# CSV file "repositories/repository_data45.csv" created successfully!
# Il reste 12133
# CSV file "repositories/repository_data46.csv" created successfully!
# Il reste 12034
# CSV file "repositories/repository_data47.csv" created successfully!
# Il reste 11935
# CSV file "repositories/repository_data48.csv" created successfully!
# Il reste 11837
# CSV file "repositories/repository_data49.csv" created successfully!
# Il reste 11738
# CSV file "repositories/repository_data50.csv" created successfully!
# Il reste 11639
# CSV file "repositories/repository_data51.csv" created successfully!
# Il reste 11540
# CSV file "repositories/repository_data52.csv" created successfully!
# Il reste 11441
# CSV file "repositories/repository_data53.csv" created successfully!
# Il reste 11342
# CSV file "repositories/repository_data54.csv" created successfully!
# Il reste 11244
# CSV file "repositories/repository_data55.csv" created successfully!
# Il reste 11146
# CSV file "repositories/repository_data56.csv" created successfully!
# Il reste 11047
# CSV file "repositories/repository_data57.csv" created successfully!
# Il reste 10949
# CSV file "repositories/repository_data58.csv" created successfully!
# Il reste 10850
# CSV file "repositories/repository_data59.csv" created successfully!
# Il reste 10752
# CSV file "repositories/repository_data60.csv" created successfully!
# Il reste 10653
# CSV file "repositories/repository_data61.csv" created successfully!
# Il reste 10555
# CSV file "repositories/repository_data62.csv" created successfully!
# Il reste 10457
# CSV file "repositories/repository_data63.csv" created successfully!
# Il reste 10361
# CSV file "repositories/repository_data64.csv" created successfully!
# Il reste 10264
# CSV file "repositories/repository_data65.csv" created successfully!
# Il reste 10165
# CSV file "repositories/repository_data66.csv" created successfully!
# Il reste 10068
# CSV file "repositories/repository_data67.csv" created successfully!
# Il reste 9970
# CSV file "repositories/repository_data68.csv" created successfully!
# Il reste 9872
# CSV file "repositories/repository_data69.csv" created successfully!
# Il reste 9773
# CSV file "repositories/repository_data70.csv" created successfully!
# Il reste 9674
# CSV file "repositories/repository_data71.csv" created successfully!
# Il reste 9579
# CSV file "repositories/repository_data72.csv" created successfully!
# Il reste 9480
# CSV file "repositories/repository_data73.csv" created successfully!
# Il reste 9382
# CSV file "repositories/repository_data74.csv" created successfully!
# Il reste 9283
# CSV file "repositories/repository_data75.csv" created successfully!
# Il reste 9185
# CSV file "repositories/repository_data76.csv" created successfully!
# Il reste 9086
# CSV file "repositories/repository_data77.csv" created successfully!
# Il reste 8989
# CSV file "repositories/repository_data78.csv" created successfully!
# Il reste 8890
# CSV file "repositories/repository_data79.csv" created successfully!
# Il reste 8792
# CSV file "repositories/repository_data80.csv" created successfully!
# Il reste 8693
# CSV file "repositories/repository_data81.csv" created successfully!
# Il reste 8595
# CSV file "repositories/repository_data82.csv" created successfully!
# Il reste 8496
# CSV file "repositories/repository_data83.csv" created successfully!
# Il reste 8398
# CSV file "repositories/repository_data84.csv" created successfully!
# Il reste 8299
# CSV file "repositories/repository_data85.csv" created successfully!
# Il reste 8200
# CSV file "repositories/repository_data86.csv" created successfully!
# Il reste 8102
# CSV file "repositories/repository_data87.csv" created successfully!
# Il reste 8008
# CSV file "repositories/repository_data88.csv" created successfully!
# Il reste 7911
# CSV file "repositories/repository_data89.csv" created successfully!
# Il reste 7812
# CSV file "repositories/repository_data90.csv" created successfully!
# Il reste 7714
# CSV file "repositories/repository_data91.csv" created successfully!
# Il reste 7616
# CSV file "repositories/repository_data92.csv" created successfully!
# Il reste 7517
# CSV file "repositories/repository_data93.csv" created successfully!
# Il reste 7418
# CSV file "repositories/repository_data94.csv" created successfully!
# Il reste 7322
# CSV file "repositories/repository_data95.csv" created successfully!
# Il reste 7224
# CSV file "repositories/repository_data96.csv" created successfully!
# Il reste 7125
# CSV file "repositories/repository_data97.csv" created successfully!
# Il reste 7029
# CSV file "repositories/repository_data98.csv" created successfully!
# Il reste 6934
# CSV file "repositories/repository_data99.csv" created successfully!
# Il reste 6835
# CSV file "repositories/repository_data100.csv" created successfully!
# Il reste 6740
# CSV file "repositories/repository_data101.csv" created successfully!
# Il reste 6641
# CSV file "repositories/repository_data102.csv" created successfully!
# Il reste 6543
# CSV file "repositories/repository_data103.csv" created successfully!
# Il reste 6444
# CSV file "repositories/repository_data104.csv" created successfully!
# Il reste 6348
# CSV file "repositories/repository_data105.csv" created successfully!
# Il reste 6252
# CSV file "repositories/repository_data106.csv" created successfully!
# Il reste 6154
# CSV file "repositories/repository_data107.csv" created successfully!
# Il reste 6059
# CSV file "repositories/repository_data108.csv" created successfully!
# Il reste 5961
# CSV file "repositories/repository_data109.csv" created successfully!
# Il reste 5863
# CSV file "repositories/repository_data110.csv" created successfully!
# Il reste 5764
# CSV file "repositories/repository_data111.csv" created successfully!
# Il reste 5665
# CSV file "repositories/repository_data112.csv" created successfully!
# Il reste 5569
# CSV file "repositories/repository_data113.csv" created successfully!
# Il reste 5475
# CSV file "repositories/repository_data114.csv" created successfully!
# Il reste 5380
# CSV file "repositories/repository_data115.csv" created successfully!
# Il reste 5282
# CSV file "repositories/repository_data116.csv" created successfully!
# Il reste 5183
# CSV file "repositories/repository_data117.csv" created successfully!
# Il reste 5086
# CSV file "repositories/repository_data118.csv" created successfully!
# Il reste 4990
# CSV file "repositories/repository_data119.csv" created successfully!
# Il reste 4893
# CSV file "repositories/repository_data120.csv" created successfully!
# Il reste 4794
# CSV file "repositories/repository_data121.csv" created successfully!
# Il reste 4696
# CSV file "repositories/repository_data122.csv" created successfully!
# Il reste 4600
# CSV file "repositories/repository_data123.csv" created successfully!
# Il reste 4503
# CSV file "repositories/repository_data124.csv" created successfully!
# Il reste 4405
# CSV file "repositories/repository_data125.csv" created successfully!
# Il reste 4306
# CSV file "repositories/repository_data126.csv" created successfully!
# Il reste 4209
# CSV file "repositories/repository_data127.csv" created successfully!
# Il reste 4114
# CSV file "repositories/repository_data128.csv" created successfully!
# Il reste 4020
# CSV file "repositories/repository_data129.csv" created successfully!
# Il reste 3922
# CSV file "repositories/repository_data130.csv" created successfully!
# Il reste 3825
# CSV file "repositories/repository_data131.csv" created successfully!
# Il reste 3730
# CSV file "repositories/repository_data132.csv" created successfully!
# Il reste 3631
# CSV file "repositories/repository_data133.csv" created successfully!
# Il reste 3533
# CSV file "repositories/repository_data134.csv" created successfully!
# Il reste 3434
# CSV file "repositories/repository_data135.csv" created successfully!
# Il reste 3338
# CSV file "repositories/repository_data136.csv" created successfully!
# Il reste 3243
# CSV file "repositories/repository_data137.csv" created successfully!
# Il reste 3148
# CSV file "repositories/repository_data138.csv" created successfully!
# Il reste 3055
# CSV file "repositories/repository_data139.csv" created successfully!
# Il reste 2958
# CSV file "repositories/repository_data140.csv" created successfully!
# Il reste 2864
# CSV file "repositories/repository_data141.csv" created successfully!
# Il reste 2768
# CSV file "repositories/repository_data142.csv" created successfully!
# Il reste 2672
# CSV file "repositories/repository_data143.csv" created successfully!
# Il reste 2579
# CSV file "repositories/repository_data144.csv" created successfully!
# Il reste 2482
# CSV file "repositories/repository_data145.csv" created successfully!
# Il reste 2383
# CSV file "repositories/repository_data146.csv" created successfully!
# Il reste 2287
# CSV file "repositories/repository_data147.csv" created successfully!
# Il reste 2195
# CSV file "repositories/repository_data148.csv" created successfully!
# Il reste 2105
# CSV file "repositories/repository_data149.csv" created successfully!
# Il reste 2010
# CSV file "repositories/repository_data150.csv" created successfully!
# Il reste 1917
# CSV file "repositories/repository_data151.csv" created successfully!
# Il reste 1820
# CSV file "repositories/repository_data152.csv" created successfully!
# Il reste 1726
# CSV file "repositories/repository_data153.csv" created successfully!
# Il reste 1631
# CSV file "repositories/repository_data154.csv" created successfully!
# Il reste 1532
# CSV file "repositories/repository_data155.csv" created successfully!
# Il reste 1434
# CSV file "repositories/repository_data156.csv" created successfully!
# Il reste 1336
# CSV file "repositories/repository_data157.csv" created successfully!
# Il reste 1237
# CSV file "repositories/repository_data158.csv" created successfully!
# Il reste 1142
# CSV file "repositories/repository_data159.csv" created successfully!
# Il reste 1047
# CSV file "repositories/repository_data160.csv" created successfully!
# Il reste 951
# CSV file "repositories/repository_data161.csv" created successfully!
# Il reste 860
# CSV file "repositories/repository_data162.csv" created successfully!
# Il reste 762
# CSV file "repositories/repository_data163.csv" created successfully!
# Il reste 671
# CSV file "repositories/repository_data164.csv" created successfully!
# Il reste 572
# CSV file "repositories/repository_data165.csv" created successfully!
# Il reste 475
# CSV file "repositories/repository_data166.csv" created successfully!
# Il reste 381
# CSV file "repositories/repository_data167.csv" created successfully!
# Il reste 283
# CSV file "repositories/repository_data168.csv" created successfully!
# Il reste 187
# CSV file "repositories/repository_data169.csv" created successfully!
# Il reste 88
# CSV file "repositories/repository_data170.csv" created successfully!
# Il reste 5
# Terminé !

# %%
# Out:
# CSV files merged successfully!

# %%
import pandas as pd
df = pd.read_csv('merged_file.csv')

# df['Date creation'] = pd.to_datetime(df['Date creation'])

df
# Out:
#                               Name
# 0                     freeCodeCamp  \
# 1           free-programming-books
# 2                          996.ICU
# 3      coding-interview-university
# 4                          awesome
# ...                            ...
# 16888                Dapp-Learning
# 16889                          boa
# 16890                     TVBoxOSC
# 16891                 lualine.nvim
# 16892                    SwiftSoup
#
#                                              Description   Stars
# 0      freeCodeCamp.org's open-source codebase and cu...  368653  \
# 1             :books: Freely available programming books  283499
# 2      Repo for counting stars and contributing. Pres...  266309
# 3      A complete computer science study plan to beco...  259647
# 4      😎 Awesome lists about all kinds of interesting...  257954
# ...                                                  ...     ...
# 16888  Dapp learning project for developers at all st...    3951
# 16889  Boa is an embeddable and experimental Javascri...    3951
# 16890                                                NaN    3951
# 16891  A blazing fast and easy to configure neovim st...    3951
# 16892  SwiftSoup: Pure Swift HTML Parser, with best o...    3951
#
#                                                      URL
# 0           https://github.com/freeCodeCamp/freeCodeCamp  \
# 1      https://github.com/EbookFoundation/free-progra...
# 2                      https://github.com/996icu/996.ICU
# 3      https://github.com/jwasham/coding-interview-un...
# 4                https://github.com/sindresorhus/awesome
# ...                                                  ...
# 16888  https://github.com/Dapp-Learning-DAO/Dapp-Lear...
# 16889                     https://github.com/boa-dev/boa
# 16890                 https://github.com/pvqogw/TVBoxOSC
# 16891       https://github.com/nvim-lualine/lualine.nvim
# 16892                https://github.com/scinfu/SwiftSoup
#
#               Date creation  Dernier modification  Forks    Language
# 0      2014-12-24T17:49:19Z  2023-06-15T20:31:23Z  32430  TypeScript
# 1      2013-10-11T06:50:37Z  2023-06-15T20:36:10Z  55707         NaN
# 2      2019-03-26T07:31:14Z  2023-06-15T20:26:48Z  21431         NaN
# 3      2016-06-06T02:34:12Z  2023-06-15T19:55:56Z  68111         NaN
# 4      2014-07-11T13:42:37Z  2023-06-15T20:33:04Z  25911         NaN
# ...                     ...                   ...    ...         ...
# 16888  2021-06-08T13:54:10Z  2023-06-15T09:22:14Z   1067    Solidity
# 16889  2018-08-08T22:20:05Z  2023-06-15T03:18:40Z    344        Rust
# 16890  2022-06-25T02:05:12Z  2023-06-15T14:57:46Z    771         NaN
# 16891  2020-12-30T14:35:10Z  2023-06-15T12:43:23Z    390         Lua
# 16892  2016-11-18T23:20:04Z  2023-06-15T09:11:01Z    283       Swift
#
# [16893 rows x 8 columns]

# %%
# Grouper et calculer la somme des langages
language_sum = df.groupby('Language').size().reset_index(name='Total')

# Trier par ordre décroissant de la somme
language_sum = language_sum.sort_values('Total', ascending=False)

# Afficher le résultat
language_sum.head(20)
# Out:
#              Language  Total
# 66         JavaScript   2787
# 107            Python   2301
# 65               Java   1290
# 136        TypeScript   1283
# 52                 Go   1274
# 22                C++    836
# 20                  C    649
# 95                PHP    501
# 21                 C#    442
# 56               HTML    423
# 117              Rust    393
# 132             Swift    369
# 125             Shell    367
# 116              Ruby    341
# 90        Objective-C    337
# 70   Jupyter Notebook    321
# 25                CSS    193
# 71             Kotlin    179
# 145               Vue    121
# 36               Dart     95

# %%
# Remove any duplicate rows
df = df.drop_duplicates()

df
# Out:
#                               Name
# 0                     freeCodeCamp  \
# 1           free-programming-books
# 2                          996.ICU
# 3      coding-interview-university
# 4                          awesome
# ...                            ...
# 16883          clojure-style-guide
# 16884                         json
# 16885                      tracing
# 16886             M13ProgressSuite
# 16887                     pikapika
#
#                                              Description   Stars
# 0      freeCodeCamp.org's open-source codebase and cu...  368653  \
# 1             :books: Freely available programming books  283499
# 2      Repo for counting stars and contributing. Pres...  266309
# 3      A complete computer science study plan to beco...  259647
# 4      😎 Awesome lists about all kinds of interesting...  257954
# ...                                                  ...     ...
# 16883  A community coding style guide for the Clojure...    3952
# 16884               Strongly typed JSON library for Rust    3952
# 16885                Application level tracing for Rust.    3952
# 16886  A suite containing many tools to display progr...    3952
# 16887   美观易用且无广告的漫画和游戏客户端，同时支持MacOS，Windows，Android，iOS。    3952
#
#                                                      URL
# 0           https://github.com/freeCodeCamp/freeCodeCamp  \
# 1      https://github.com/EbookFoundation/free-progra...
# 2                      https://github.com/996icu/996.ICU
# 3      https://github.com/jwasham/coding-interview-un...
# 4                https://github.com/sindresorhus/awesome
# ...                                                  ...
# 16883     https://github.com/bbatsov/clojure-style-guide
# 16884                   https://github.com/serde-rs/json
# 16885                https://github.com/tokio-rs/tracing
# 16886       https://github.com/Marxon13/M13ProgressSuite
# 16887                https://github.com/niuhuan/pikapika
#
#               Date creation  Dernier modification  Forks     Language
# 0      2014-12-24T17:49:19Z  2023-06-15T20:31:23Z  32430   TypeScript
# 1      2013-10-11T06:50:37Z  2023-06-15T20:36:10Z  55707          NaN
# 2      2019-03-26T07:31:14Z  2023-06-15T20:26:48Z  21431          NaN
# 3      2016-06-06T02:34:12Z  2023-06-15T19:55:56Z  68111          NaN
# 4      2014-07-11T13:42:37Z  2023-06-15T20:33:04Z  25911          NaN
# ...                     ...                   ...    ...          ...
# 16883  2013-01-03T18:09:53Z  2023-06-15T07:55:51Z    278          NaN
# 16884  2015-05-19T16:30:20Z  2023-06-13T08:18:07Z    479         Rust
# 16885  2019-01-11T18:17:15Z  2023-06-15T10:27:47Z    544         Rust
# 16886  2013-12-23T18:05:36Z  2023-06-12T08:37:04Z    541  Objective-C
# 16887  2021-07-27T01:25:07Z  2023-06-15T18:20:57Z    278         Dart
#
# [16480 rows x 8 columns]
